# %%
                        # *****************CREATING VARIABLES IN CLASS********************

# %%
class basicclass:
 actor = "Raju"
 actress = "Rose"
 producer = "Param"
 director = "Karthika"

# %%
mve = basicclass()
mve.director
# Out:
# 'Karthika'

# %%
mve.actress
# Out:
# 'Rose'

# %%
mve.actor
# Out:
# 'Raju'

# %%
          # *************CREATING FUNCTIONS IN CLASS*********************************************************

# %%
class basic_movie:
 actor = "Raju"
 actress = "Rose"
 producer = "Param"
 director = "Karthika"
 def production():
     return "Karthika productions"

# %%
v=basic_movie
v.director
# Out:
# 'Karthika'

# %%
v.production()
# Out:
# 'Karthika productions'

# %%
          # *************CREATING FUNCTIONS IN CLASS   AND CALL THE FUNCTION*********************************************************

# %%
class basic_movie1:
 actor = "Raju"
 actress = "Rose"
 producer = "Param"
 director = "Karthika"
 def production(self):
     a=self.actor+"Karthika productions"
     b=self.director+"Karthika productions"
     return b

# %%
v1=basic_movie1()

# %%
v1.actor
# Out:
# 'Raju'

# %%
v1.production()
# Out:
# 'KarthikaKarthika productions'

# %%
class filmindustary:
    hero="NTR"
    heroine = "Kajal"
    director = "Karthi"
    producor = "Param"
    def industary(self):
        v=self.director + "Anu productions"
        return v

# %%
df=filmindustary()

# %%
df.hero
# Out:
# 'NTR'

# %%
df.industary()
# Out:
# 'KarthiAnu productions'

# %%
 # ***************ADDING CONSTRUCTOR TO A CLASS*********************

# %%
class movie:#type of calss = movie details
    def __init__(self,actor,producer,director):
        self.actor = actor
        self.producer= producer
        self.director = director
    def production (self):
        pro=self.director + "kathi_productions"
        return pro

# %%
actionmovie= movie("PSPK","karthi","Anu")

# %%
actionmovie

# %%
actionmovie.producer
# Out:
# 'karthi'

# %%
# basicmovie.producer

# %%
actionmovie.production()
# Out:
# 'Anukathi_productions'

# %%
class fashiondesigning:
    def __init__(self,name,location):
        self.name=name
        self.location=location
    def fashion(self):
        var=self.name + "super_fashion"
        return var

# %%
var1=fashiondesigning("mouni","MTM")

# %%
var1.name
# Out:
# 'mouni'

# %%
var1.location
# Out:
# 'MTM'

# %%
var1.fashion()
# Out:
# 'mounisuper_fashion'

# %%
class maths:
    def __init__(self,a,b):
        self.a=a
        self.a=b
    def addition_P(a,b):
        c=a+b
        return c

# %%
var2=maths

# %%
var2
# Out:
# __main__.maths

# %%
var2.addition_P(255,5)
# Out:
# 260
